# %% [markdown]
# #Assurance API for DNA-Center

# %%
from util import get_url
import json
import time

# %%
response = get_url("dna/intent/api/v1/network-health?startTime=&endTime=", headers={})
# Out:
# https://sandboxdnac.cisco.com:443/dna/intent/api/v1/network-health?startTime=&endTime=

# %%
print json.dumps(response, indent=2)
# Out:
# {
#   "executionStatusUrl": "https://10.10.20.102/api/dnacaap/v1/dnacaap/management/execution-status/4978c428-9f65-4c0f-9349-4f4453375865",
#   "executionId": "4978c428-9f65-4c0f-9349-4f4453375865",
#   "message": "The request has been accepted for execution"
# }

# %%
response = get_url("api/dnacaap/v1/dnacaap/management/execution-status/{}".format(response['executionId']))
# Out:
# https://sandboxdnac.cisco.com:443/api/dnacaap/v1/dnacaap/management/execution-status/4978c428-9f65-4c0f-9349-4f4453375865

# %%
print json.dumps(json.loads(response['bapiSyncResponse']), indent=2)
# Out:
# {
#   "response": {
#     "latestMeasuredByEntity": null,
#     "healthDistirubution": [
#       {
#         "category": "Access",
#         "badPercentage": 0,
#         "fairPercentage": 0,
#         "totalCount": 2,
#         "healthScore": 100,
#         "goodPercentage": 100
#       },
#       {
#         "category": "Distribution",
#         "badPercentage": 0,
#         "fairPercentage": 0,
#         "totalCount": 1,
#         "healthScore": 100,
#         "goodPercentage": 100
#       },
#       {
#         "category": "Router",
#         "badPercentage": 0,
#         "fairPercentage": 0,
#         "totalCount": 1,
#         "healthScore": 100,
#         "goodPercentage": 100
#       }
#     ],
#     "measuredBy": "global",
#     "latestHealthScore": 100,
#     "monitoredDevices": 4,
#     "unMonitoredDevices": 0
#   }
# }

# %%
response = get_url("dna/intent/api/v1/site-hierarchy?timestamp=",
                   headers={'__runsync': 'true'})
response = get_url("api/dnacaap/v1/dnacaap/management/execution-status/{}".format(response['executionId']))
response = json.loads(response['bapiSyncResponse'])
# Out:
# https://sandboxdnac.cisco.com:443/dna/intent/api/v1/site-hierarchy?timestamp=
# https://sandboxdnac.cisco.com:443/api/dnacaap/v1/dnacaap/management/execution-status/e3303e93-de5e-493d-8ca5-0099611583cf

# %%
print json.dumps(response,indent=2)
# Out:
# {
#   "response": [
#     {
#       "networkHealthCore": null,
#       "numberOfNetworkDevice": 4,
#       "siteName": " All Sites",
#       "siteType": "area",
#       "networkNumberOfIssues": null,
#       "routerTotalCount": 1,
#       "applicationBytesTotalCount": null,
#       "numberOfWirelessClients": 0,
#       "accessGoodCount": 2,
#       "wiredGoodClients": 0,
#       "clientHealthWired": null,
#       "numberOfWiredClients": 0,
#       "coreGoodCount": -1,
#       "applicationHealth": null,
#       "distributionTotalCount": 1,
#       "networkHealthRouter": 100,
#       "clientHealthWireless": null,
#       "networkHealthOthers": null,
#       "networkHealthAccess": 100,
#       "clientNumberOfIssues": null,
#       "healthyNetworkDevicePercentage": 100,
#       "parentSiteId": null,
#       "networkHealthAverage": null,
#       "accessTotalCount": 2,
#       "distributionGoodCount": 1,
#       "siteId": " All Sites",
#       "healthyClientsPercentage": null,
#       "wirelessGoodClients": 0,
#       "wirelessDeviceTotalCount": 0,
#       "numberOfClients": 0,
#       "networkHealthWireless": null,
#       "routerGoodCount": 1,
#       "networkHealthDistribution": 100,
#       "parentSiteName": null,
#       "applicationTotalCount": null,
#       "coreTotalCount": -1,
#       "wirelessDeviceGoodCount": 0,
#       "clientIssueCount": 0,
#       "applicationGoodCount": null,
#       "overallGoodDevices": 4
#     },
#     {
#       "networkHealthCore": null,
#       "numberOfNetworkDevice": 3,
#       "siteName": "NSD5",
#       "siteType": "building",
#       "networkNumberOfIssues": null,
#       "routerTotalCount": -1,
#       "applicationBytesTotalCount": null,
#       "numberOfWirelessClients": 0,
#       "accessGoodCount": 2,
#       "wiredGoodClients": 0,
#       "clientHealthWired": null,
#       "numberOfWiredClients": 0,
#       "coreGoodCount": -1,
#       "applicationHealth": null,
#       "distributionTotalCount": 1,
#       "networkHealthRouter": null,
#       "clientHealthWireless": null,
#       "networkHealthOthers": null,
#       "networkHealthAccess": 100,
#       "clientNumberOfIssues": null,
#       "healthyNetworkDevicePercentage": 100,
#       "parentSiteId": "73fe5831-4f28-4b61-9522-31be438fcb21",
#       "networkHealthAverage": null,
#       "accessTotalCount": 2,
#       "distributionGoodCount": 1,
#       "siteId": "5f0c35d5-bc8f-4923-97e7-51a530393d15",
#       "healthyClientsPercentage": null,
#       "wirelessGoodClients": 0,
#       "wirelessDeviceTotalCount": 0,
#       "numberOfClients": 0,
#       "networkHealthWireless": null,
#       "routerGoodCount": -1,
#       "networkHealthDistribution": 100,
#       "parentSiteName": "Sydney",
#       "applicationTotalCount": null,
#       "coreTotalCount": -1,
#       "wirelessDeviceGoodCount": 0,
#       "clientIssueCount": 0,
#       "applicationGoodCount": null,
#       "overallGoodDevices": 3
#     },
#     {
#       "networkHealthCore": null,
#       "numberOfNetworkDevice": 1,
#       "siteName": "Melbourne",
#       "siteType": "area",
#       "networkNumberOfIssues": null,
#       "routerTotalCount": 1,
#       "applicationBytesTotalCount": null,
#       "numberOfWirelessClients": 0,
#       "accessGoodCount": -1,
#       "wiredGoodClients": 0,
#       "clientHealthWired": null,
#       "numberOfWiredClients": 0,
#       "coreGoodCount": -1,
#       "applicationHealth": null,
#       "distributionTotalCount": -1,
#       "networkHealthRouter": 100,
#       "clientHealthWireless": null,
#       "networkHealthOthers": null,
#       "networkHealthAccess": null,
#       "clientNumberOfIssues": null,
#       "healthyNetworkDevicePercentage": 100,
#       "parentSiteId": " All Sites",
#       "networkHealthAverage": null,
#       "accessTotalCount": -1,
#       "distributionGoodCount": -1,
#       "siteId": "ff29eff4-87d5-4203-aafd-5de50b554ef0",
#       "healthyClientsPercentage": null,
#       "wirelessGoodClients": 0,
#       "wirelessDeviceTotalCount": 0,
#       "numberOfClients": 0,
#       "networkHealthWireless": null,
#       "routerGoodCount": 1,
#       "networkHealthDistribution": null,
#       "parentSiteName": " All Sites",
#       "applicationTotalCount": null,
#       "coreTotalCount": -1,
#       "wirelessDeviceGoodCount": 0,
#       "clientIssueCount": 0,
#       "applicationGoodCount": null,
#       "overallGoodDevices": 1
#     },
#     {
#       "networkHealthCore": null,
#       "numberOfNetworkDevice": 3,
#       "siteName": "Sydney",
#       "siteType": "area",
#       "networkNumberOfIssues": null,
#       "routerTotalCount": -1,
#       "applicationBytesTotalCount": null,
#       "numberOfWirelessClients": 0,
#       "accessGoodCount": 2,
#       "wiredGoodClients": 0,
#       "clientHealthWired": null,
#       "numberOfWiredClients": 0,
#       "coreGoodCount": -1,
#       "applicationHealth": null,
#       "distributionTotalCount": 1,
#       "networkHealthRouter": null,
#       "clientHealthWireless": null,
#       "networkHealthOthers": null,
#       "networkHealthAccess": 100,
#       "clientNumberOfIssues": null,
#       "healthyNetworkDevicePercentage": 100,
#       "parentSiteId": " All Sites",
#       "networkHealthAverage": null,
#       "accessTotalCount": 2,
#       "distributionGoodCount": 1,
#       "siteId": "73fe5831-4f28-4b61-9522-31be438fcb21",
#       "healthyClientsPercentage": null,
#       "wirelessGoodClients": 0,
#       "wirelessDeviceTotalCount": 0,
#       "numberOfClients": 0,
#       "networkHealthWireless": null,
#       "routerGoodCount": -1,
#       "networkHealthDistribution": 100,
#       "parentSiteName": " All Sites",
#       "applicationTotalCount": null,
#       "coreTotalCount": -1,
#       "wirelessDeviceGoodCount": 0,
#       "clientIssueCount": 0,
#       "applicationGoodCount": null,
#       "overallGoodDevices": 3
#     },
#     {
#       "networkHealthCore": null,
#       "numberOfNetworkDevice": 1,
#       "siteName": "MEL2",
#       "siteType": "building",
#       "networkNumberOfIssues": null,
#       "routerTotalCount": 1,
#       "applicationBytesTotalCount": null,
#       "numberOfWirelessClients": 0,
#       "accessGoodCount": -1,
#       "wiredGoodClients": 0,
#       "clientHealthWired": null,
#       "numberOfWiredClients": 0,
#       "coreGoodCount": -1,
#       "applicationHealth": null,
#       "distributionTotalCount": -1,
#       "networkHealthRouter": 100,
#       "clientHealthWireless": null,
#       "networkHealthOthers": null,
#       "networkHealthAccess": null,
#       "clientNumberOfIssues": null,
#       "healthyNetworkDevicePercentage": 100,
#       "parentSiteId": "ff29eff4-87d5-4203-aafd-5de50b554ef0",
#       "networkHealthAverage": null,
#       "accessTotalCount": -1,
#       "distributionGoodCount": -1,
#       "siteId": "c0b7b7de-b96d-46c7-b494-336077d54b5b",
#       "healthyClientsPercentage": null,
#       "wirelessGoodClients": 0,
#       "wirelessDeviceTotalCount": 0,
#       "numberOfClients": 0,
#       "networkHealthWireless": null,
#       "routerGoodCount": 1,
#       "networkHealthDistribution": null,
#       "parentSiteName": "Melbourne",
#       "applicationTotalCount": null,
#       "coreTotalCount": -1,
#       "wirelessDeviceGoodCount": 0,
#       "clientIssueCount": 0,
#       "applicationGoodCount": null,
#       "overallGoodDevices": 1
#     },
#     {
#       "networkHealthCore": null,
#       "numberOfNetworkDevice": 4,
#       "siteName": " All Buildings",
#       "siteType": "building",
#       "networkNumberOfIssues": null,
#       "routerTotalCount": null,
#       "applicationBytesTotalCount": null,
#       "numberOfWirelessClients": null,
#       "accessGoodCount": null,
#       "wiredGoodClients": null,
#       "clientHealthWired": null,
#       "numberOfWiredClients": null,
#       "coreGoodCount": null,
#       "applicationHealth": null,
#       "distributionTotalCount": null,
#       "networkHealthRouter": 100,
#       "clientHealthWireless": null,
#       "networkHealthOthers": null,
#       "networkHealthAccess": 100,
#       "clientNumberOfIssues": null,
#       "healthyNetworkDevicePercentage": 100,
#       "parentSiteId": null,
#       "networkHealthAverage": null,
#       "accessTotalCount": null,
#       "distributionGoodCount": null,
#       "siteId": " All Buildings",
#       "healthyClientsPercentage": null,
#       "wirelessGoodClients": null,
#       "wirelessDeviceTotalCount": null,
#       "numberOfClients": 0,
#       "networkHealthWireless": null,
#       "routerGoodCount": null,
#       "networkHealthDistribution": 100,
#       "parentSiteName": null,
#       "applicationTotalCount": null,
#       "coreTotalCount": null,
#       "wirelessDeviceGoodCount": null,
#       "clientIssueCount": 0,
#       "applicationGoodCount": null,
#       "overallGoodDevices": null
#     }
#   ]
# }

# %%
print "\n".join(["Site:{}, NwkHealth:{}".format(res['siteName'], 
                      res['networkHealthAccess'])
           for res in response['response']])
# Out:
# Site: All Sites, NwkHealth:100
# Site:NSD5, NwkHealth:100
# Site:Melbourne, NwkHealth:None
# Site:Sydney, NwkHealth:100
# Site:MEL2, NwkHealth:None
# Site: All Buildings, NwkHealth:100

# %%
response = get_url("dna/intent/api/v1/client-health?startTime=&endTime=",
                   headers={'__runsync': 'true'}) 
response = get_url("api/dnacaap/v1/dnacaap/management/execution-status/{}".format(response['executionId']))
response = json.loads(response['bapiSyncResponse'])
# Out:
# https://sandboxdnac.cisco.com:443/dna/intent/api/v1/client-health?startTime=&endTime=
# https://sandboxdnac.cisco.com:443/api/dnacaap/v1/dnacaap/management/execution-status/063f7e7c-92ce-473a-a528-3ec62a1c9d39

# %%
print json.dumps(response,indent=2)
# Out:
# {
#   "response": [
#     {
#       "scoreDetail": [
#         {
#           "scoreValue": -1,
#           "clientUniqueCount": 0,
#           "scoreCategory": {
#             "scoreCategory": "CLIENT_TYPE",
#             "value": "ALL"
#           },
#           "starttime": 1534890900892,
#           "clientCount": 0,
#           "endtime": 1534891200892,
#           "scoreList": []
#         },
#         {
#           "scoreValue": -1,
#           "clientUniqueCount": 0,
#           "scoreCategory": {
#             "scoreCategory": "CLIENT_TYPE",
#             "value": "WIRED"
#           },
#           "starttime": 1534890900892,
#           "clientCount": 0,
#           "endtime": 1534891200892,
#           "scoreList": [
#             {
#               "scoreValue": -1,
#               "clientUniqueCount": 0,
#               "scoreCategory": {
#                 "scoreCategory": "SCORE_TYPE",
#                 "value": "POOR"
#               },
#               "starttime": 1534890900892,
#               "clientCount": 0,
#               "endtime": 1534891200892,
#               "scoreList": []
#             },
#             {
#               "scoreValue": -1,
#               "clientUniqueCount": 0,
#               "scoreCategory": {
#                 "scoreCategory": "SCORE_TYPE",
#                 "value": "FAIR"
#               },
#               "starttime": 1534890900892,
#               "clientCount": 0,
#               "endtime": 1534891200892,
#               "scoreList": []
#             },
#             {
#               "scoreValue": -1,
#               "clientUniqueCount": 0,
#               "scoreCategory": {
#                 "scoreCategory": "SCORE_TYPE",
#                 "value": "GOOD"
#               },
#               "starttime": 1534890900892,
#               "clientCount": 0,
#               "endtime": 1534891200892,
#               "scoreList": []
#             },
#             {
#               "scoreValue": -1,
#               "clientUniqueCount": 0,
#               "scoreCategory": {
#                 "scoreCategory": "SCORE_TYPE",
#                 "value": "IDLE"
#               },
#               "starttime": 1534890900892,
#               "clientCount": 0,
#               "endtime": 1534891200892,
#               "scoreList": []
#             }
#           ]
#         },
#         {
#           "scoreValue": -1,
#           "clientUniqueCount": 0,
#           "scoreCategory": {
#             "scoreCategory": "CLIENT_TYPE",
#             "value": "WIRELESS"
#           },
#           "starttime": 1534890900892,
#           "clientCount": 0,
#           "endtime": 1534891200892,
#           "scoreList": [
#             {
#               "scoreValue": -1,
#               "clientUniqueCount": 0,
#               "scoreCategory": {
#                 "scoreCategory": "SCORE_TYPE",
#                 "value": "POOR"
#               },
#               "starttime": 1534890900892,
#               "clientCount": 0,
#               "endtime": 1534891200892,
#               "scoreList": []
#             },
#             {
#               "scoreValue": -1,
#               "clientUniqueCount": 0,
#               "scoreCategory": {
#                 "scoreCategory": "SCORE_TYPE",
#                 "value": "FAIR"
#               },
#               "starttime": 1534890900892,
#               "clientCount": 0,
#               "endtime": 1534891200892,
#               "scoreList": []
#             },
#             {
#               "scoreValue": -1,
#               "clientUniqueCount": 0,
#               "scoreCategory": {
#                 "scoreCategory": "SCORE_TYPE",
#                 "value": "GOOD"
#               },
#               "starttime": 1534890900892,
#               "clientCount": 0,
#               "endtime": 1534891200892,
#               "scoreList": []
#             },
#             {
#               "scoreValue": -1,
#               "clientUniqueCount": 0,
#               "scoreCategory": {
#                 "scoreCategory": "SCORE_TYPE",
#                 "value": "IDLE"
#               },
#               "starttime": 1534890900892,
#               "clientCount": 0,
#               "endtime": 1534891200892,
#               "scoreList": []
#             }
#           ]
#         }
#       ],
#       "siteId": "global"
#     }
#   ]
# }

# %%
timestamp=time.time()
mac="00:1E:13:A5:B9:40"
url='dna/intent/api/v1/client-detail?timestamp={}&macAddress={}'.format(timestamp,mac)
response = get_url(url, headers={'__runsync': 'true'})

# %%
print json.dumps(response,indent=2)
